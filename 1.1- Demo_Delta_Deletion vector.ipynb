# %%
# %sql
use catalog my_catalog;
use schema test

# %%
data = [(1,"India","Cricket"),(2,"Australia","Cricket"),(3,"India","Tennis"),(4,"USA","Baseball"),(5,"China","Badminton")]
spark.createDataFrame(data,["id","country","game"]).write.mode("overwrite").save("/Volumes/my_catalog/test/test_volume/test_games1")

# %%
# %sql
select * from delta.`/Volumes/my_catalog/test/test_volume/test_games1`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>country</th><th>game</th></tr></thead><tbody><tr><td>1</td><td>India</td><td>Cricket</td></tr><tr><td>2</td><td>Australia</td><td>Cricket</td></tr><tr><td>3</td><td>India</td><td>Tennis</td></tr><tr><td>4</td><td>USA</td><td>Baseball</td></tr><tr><td>5</td><td>China</td><td>Badminton</td></tr></tbody></table></div>

# %%
# %fs
ls /Volumes/my_catalog/test/test_volume/test_games1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/my_catalog/test/test_volume/test_games1/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1763791869384</td></tr><tr><td>dbfs:/Volumes/my_catalog/test/test_volume/test_games1/part-00000-b40b0b23-f829-4d53-a986-430a4543c26f.c000.snappy.parquet</td><td>part-00000-b40b0b23-f829-4d53-a986-430a4543c26f.c000.snappy.parquet</td><td>1185</td><td>1763791827000</td></tr></tbody></table></div>

# %%
# %fs
ls /Volumes/my_catalog/test/test_volume/test_games1/_delta_log
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/my_catalog/test/test_volume/test_games1/_delta_log/00000000000000000000.crc</td><td>00000000000000000000.crc</td><td>2881</td><td>1763791829000</td></tr><tr><td>dbfs:/Volumes/my_catalog/test/test_volume/test_games1/_delta_log/00000000000000000000.json</td><td>00000000000000000000.json</td><td>1895</td><td>1763791829000</td></tr><tr><td>dbfs:/Volumes/my_catalog/test/test_volume/test_games1/_delta_log/_staged_commits/</td><td>_staged_commits/</td><td>0</td><td>1763791882823</td></tr></tbody></table></div>

# %%
# %sql
select * from json.`/Volumes/my_catalog/test/test_volume/test_games1/_delta_log/00000000000000000000.json`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
update delta.`/Volumes/my_catalog/test/test_volume/test_games1`
set game = 'soccer'
where id=2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
describe history delta.`/Volumes/my_catalog/test/test_volume/test_games1/`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs
ls /Volumes/my_catalog/test/test_volume/test_games1/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs
ls /Volumes/my_catalog/test/test_volume/test_games1/_delta_log
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from json.`/Volumes/my_catalog/test/test_volume/test_games1/_delta_log/00000000000000000001.json`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # DELETE

# %%
dbutils.fs.rm("/Volumes/my_catalog/test/test_volume/test_games1",True)
# Out:
# True

# %%
data = [(1,"India","Cricket"),(2,"Australia","Cricket"),(3,"India","Tennis"),(4,"USA","Baseball"),(5,"China","Badminton")]
spark.createDataFrame(data,["id","country","game"]).write.mode("overwrite").save("/Volumes/my_catalog/test/test_volume/test_games1")

# %%
# %sql
select * from delta.`/Volumes/my_catalog/test/test_volume/test_games1`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>country</th><th>game</th></tr></thead><tbody><tr><td>1</td><td>India</td><td>Cricket</td></tr><tr><td>2</td><td>Australia</td><td>Cricket</td></tr><tr><td>3</td><td>India</td><td>Tennis</td></tr><tr><td>4</td><td>USA</td><td>Baseball</td></tr><tr><td>5</td><td>China</td><td>Badminton</td></tr></tbody></table></div>

# %%
# %fs
ls /Volumes/my_catalog/test/test_volume/test_games1/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/my_catalog/test/test_volume/test_games1/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1763792427256</td></tr><tr><td>dbfs:/Volumes/my_catalog/test/test_volume/test_games1/part-00000-6b2211ca-fe2f-4572-87a1-e26c8ed41c3d.c000.snappy.parquet</td><td>part-00000-6b2211ca-fe2f-4572-87a1-e26c8ed41c3d.c000.snappy.parquet</td><td>1185</td><td>1763792425000</td></tr></tbody></table></div>

# %%
# %fs
ls /Volumes/my_catalog/test/test_volume/test_games1/_delta_log
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/my_catalog/test/test_volume/test_games1/_delta_log/00000000000000000000.crc</td><td>00000000000000000000.crc</td><td>2881</td><td>1763792425000</td></tr><tr><td>dbfs:/Volumes/my_catalog/test/test_volume/test_games1/_delta_log/00000000000000000000.json</td><td>00000000000000000000.json</td><td>1895</td><td>1763792425000</td></tr><tr><td>dbfs:/Volumes/my_catalog/test/test_volume/test_games1/_delta_log/_staged_commits/</td><td>_staged_commits/</td><td>0</td><td>1763792428098</td></tr></tbody></table></div>

# %%
# %sql
delete from delta.`/Volumes/my_catalog/test/test_volume/test_games1`
where id=2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
describe history delta.`/Volumes/my_catalog/test/test_volume/test_games1/`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs
ls /Volumes/my_catalog/test/test_volume/test_games1/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs
ls /Volumes/my_catalog/test/test_volume/test_games1/_delta_log
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from json.`/Volumes/my_catalog/test/test_volume/test_games1/_delta_log/00000000000000000001.json`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from json.`/Volumes/my_catalog/test/test_volume/test_games1/_delta_log/00000000000000000002.json`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
