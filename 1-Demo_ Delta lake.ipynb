# %%
# %sql

use catalog my_catalog;
use schema test

# %%
data = [(1,"Adam","USA"),(2,"Bob","Canada"),(3,"Charlie","UK"),(4,"David","Australia")]
schema  = ["id","name","country"]
df = spark.createDataFrame(data,schema)
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>country</th></tr></thead><tbody><tr><td>1</td><td>Adam</td><td>USA</td></tr><tr><td>2</td><td>Bob</td><td>Canada</td></tr><tr><td>3</td><td>Charlie</td><td>UK</td></tr><tr><td>4</td><td>David</td><td>Australia</td></tr></tbody></table></div>

# %%
df.write.mode("overwrite").save('/Volumes/my_catalog/test/test_volume/test_data1')

# %%
# %fs
ls /Volumes/my_catalog/test/test_volume/test_data1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/my_catalog/test/test_volume/test_data1/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1763692080400</td></tr><tr><td>dbfs:/Volumes/my_catalog/test/test_volume/test_data1/part-00000-37a0e19d-248c-411f-b3c4-524d9e166a58.c000.snappy.parquet</td><td>part-00000-37a0e19d-248c-411f-b3c4-524d9e166a58.c000.snappy.parquet</td><td>1094</td><td>1763692064000</td></tr></tbody></table></div>

# %%
# %fs ls /Volumes/my_catalog/test/test_volume/test_data1/_delta_log/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/my_catalog/test/test_volume/test_data1/_delta_log/00000000000000000000.crc</td><td>00000000000000000000.crc</td><td>2875</td><td>1763692066000</td></tr><tr><td>dbfs:/Volumes/my_catalog/test/test_volume/test_data1/_delta_log/00000000000000000000.json</td><td>00000000000000000000.json</td><td>1889</td><td>1763692066000</td></tr><tr><td>dbfs:/Volumes/my_catalog/test/test_volume/test_data1/_delta_log/_staged_commits/</td><td>_staged_commits/</td><td>0</td><td>1763692102148</td></tr></tbody></table></div>

# %%
# %sql
select * from json.`/Volumes/my_catalog/test/test_volume/test_data1/_delta_log/00000000000000000000.json`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
data = [(5,"Gilbert","Ireland"),(6,"Hannah","France"),(7,"Ivan","Germany")]
schema  = ["id","name","country"]
df_new = spark.createDataFrame(data,schema)
df_new.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>country</th></tr></thead><tbody><tr><td>5</td><td>Gilbert</td><td>Ireland</td></tr><tr><td>6</td><td>Hannah</td><td>France</td></tr><tr><td>7</td><td>Ivan</td><td>Germany</td></tr></tbody></table></div>

# %%
df_new.write.mode("append").save('/Volumes/my_catalog/test/test_volume/test_data1')

# %%
# %fs ls /Volumes/my_catalog/test/test_volume/test_data1/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls /Volumes/my_catalog/test/test_volume/test_data1/_delta_log/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from json.`/Volumes/my_catalog/test/test_volume/test_data1/_delta_log/00000000000000000001.json`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
DESCRIBE HISTORY delta.`/Volumes/my_catalog/test/test_volume/test_data1`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
